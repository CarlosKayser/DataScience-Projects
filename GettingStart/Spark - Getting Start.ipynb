# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, unix_timestamp, to_date, date_format
from pyspark.sql import functions as F
from pyspark.sql import types
import pandas as pd

# Criando a sessão Spark
spark = SparkSession \
        .builder \
        .appName("Getting Start") \
        .getOrCreate()

# Atributos e métodos do objeto Spark
# dir(SparkSession)

# %%
data = [("Newton", 1643), ("Einstein", 1879), ("Gaus", 1777)]
df_teste = spark.createDataFrame(data, ["Name", "Nascimento"])
df_teste.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Nascimento: long (nullable = true)

# %%
df_teste.show()
# Out:
# +--------+----------+
# |    Name|Nascimento|
# +--------+----------+
# |  Newton|      1643|
# |Einstein|      1879|
# |    Gaus|      1777|
# +--------+----------+

# %% [markdown]
# ## Usando Spark para processar um arquivo CSV

# %%
# Dados obtidos em http://www.portaltransparencia.gov.br/download-de-dados/viagens
# Do ano de 2018

df = spark.read.csv("data/Viagens 2018/2018_Viagem_UTF8.csv", header=True, sep=';')

# %%
df.printSchema()
# Out:
# root
#  |-- Identificador do processo de viagem: string (nullable = true)
#  |-- Situação: string (nullable = true)
#  |-- Código do órgão superior: string (nullable = true)
#  |-- Nome do órgão superior: string (nullable = true)
#  |-- Código órgão solicitante: string (nullable = true)
#  |-- Nome órgão solicitante: string (nullable = true)
#  |-- CPF viajante: string (nullable = true)
#  |-- Nome: string (nullable = true)
#  |-- Cargo: string (nullable = true)
#  |-- Período - Data de início: string (nullable = true)
#  |-- Período - Data de fim: string (nullable = true)
#  |-- Destinos: string (nullable = true)
#  |-- Motivo: string (nullable = true)
#  |-- Valor diárias: string (nullable = true)
#  |-- Valor passagens: string (nullable = true)
#  |-- Valor outros gastos: string (nullable = true)

# %%
df.limit(10).toPandas()
# Out:
#   Identificador do processo de viagem   Situação Código do órgão superior  \
# 0                 0000000000013501576  Realizada                    36000
# 1                 0000000000014026421  Realizada                    26000
# 2                 0000000000014046485  Realizada                    26000
# 3                 0000000000014108743  Realizada                    26000
# 4                 0000000000014112304  Realizada                    26000
# 5                 0000000000014142324  Realizada                    44000
# 6                 0000000000014146681  Realizada                    36000
# 7                 0000000000014166390  Realizada                    26000
# 8                 0000000000014199743  Realizada                    26000
# 9                 0000000000014201345  Realizada                    26000
#
#         Nome do órgão superior Código órgão solicitante  \
# 0          MINISTERIO DA SAUDE                    36201
# 1       MINISTERIO DA EDUCACAO                    26352
# 2       MINISTERIO DA EDUCACAO                    26405
# 3       MINISTERIO DA EDUCACAO                    26258
# 4       MINISTERIO DA EDUCACAO                    26279
# 5  MINISTERIO DO MEIO AMBIENTE                    44207
# 6          MINISTERIO DA SAUDE                    36201
# 7       MINISTERIO DA EDUCACAO                    26258
# 8       MINISTERIO DA EDUCACAO                    26258
# 9       MINISTERIO DA EDUCACAO                    26241
#
#                           Nome órgão solicitante    CPF viajante  \
# 0                          FUNDACAO OSWALDO CRUZ  ***.637.54*-**
# 1           FUNDACAO UNIVERSIDADE FEDERAL DO ABC  ***.199.59*-**
# 2         INST.FED.DE EDUC.,CIENC.E TEC.DO CEARA  ***.061.02*-**
# 3     UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA  ***.414.38*-**
# 4         FUNDACAO UNIVERSIDADE FEDERAL DO PIAUI  ***.836.65*-**
# 5  INST.CHICO MENDES DE CONSER.DA BIODIVERSIDADE  ***.852.04*-**
# 6                          FUNDACAO OSWALDO CRUZ  ***.258.30*-**
# 7     UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA  ***.477.30*-**
# 8     UNIVERSIDADE TECNOLOGICA FEDERAL DO PARANA  ***.583.61*-**
# 9                 UNIVERSIDADE FEDERAL DO PARANA  ***.241.50*-**
#
#                                    Nome  \
# 0  ELIANE CALDAS DO NASCIMENTO OLIVEIRA
# 1                 ALYSSON FABIO FERRARI
# 2          REGINA LUCIA BEZERRA VASQUES
# 3        JULIANA BORTOLI RODRIGUES MEES
# 4       FRANCISCO DE ASSIS SINIMBU NETO
# 5                   CARINA TOSTES ABREU
# 6                ARLINDA BARBOSA MORENO
# 7               RAFAEL SOARES DE ARRUDA
# 8             RAFAELA ANTUNES FORTUNATO
# 9                            HUGO VERLI
#
#                                    Cargo Período - Data de início  \
# 0           PESQUISADOR EM SAUDE PUBLICA                 20180210
# 1       PROFESSOR DO MAGISTERIO SUPERIOR                 20180109
# 2                                   None                 20180223
# 3  PROFESSOR ENS BASICO TECN TECNOLOGICO                 20180117
# 4  PROFESSOR ENS BASICO TECN TECNOLOGICO                 20180104
# 5                     ANALISTA AMBIENTAL                 20180108
# 6           PESQUISADOR EM SAUDE PUBLICA                 20180102
# 7       PROFESSOR DO MAGISTERIO SUPERIOR                 20180218
# 8  PROFESSOR ENS BASICO TECN TECNOLOGICO                 20180201
# 9       PROFESSOR DO MAGISTERIO SUPERIOR                 20180125
#
#   Período - Data de fim                                         Destinos  \
# 0              20180302                                 Coimbra/Portugal
# 1              20181119  Bloomington - Indiana/Estados Unidos da América
# 2              20180225                                       Meruoca/CE
# 3              20180216                                  Lisboa/Portugal
# 4              20180106                                     Bom Jesus/PI
# 5              20180407               Honolulu/Estados Unidos da América
# 6              20180405                              Londres/Reino Unido
# 7              20180224                                  Campo Mourão/PR
# 8              20180228                                   Porto/Portugal
# 9              20180126                                      Curitiba/PR
#
#                                               Motivo Valor diárias  \
# 0  PARTICIPAÇÃO EM PROJETOS DE PESQUISA DESENVOLV...           ,00
# 1                  Estágio pós-doutoral no exterior.           ,00
# 2  Realizar o  encontro presencial da Disciplina ...        537,50
# 3  "Estágio/Intercâmbio Internacional no IPPORTO ...           ,00
# 4  o mesmo participará de solenidades de FORMATUR...        487,11
# 5  Trata o presente processo da solicitação de Li...           ,00
# 6  ESTÁGIO DE APERFEIÇOAMENTO COMO PESQUISADORA V...           ,00
# 7  "O proposto ministrará o curso de Capacitação ...           ,00
# 8  "Executar o projeto de inovação "Método de Ens...           ,00
# 9  Participar de defesa de tese de doutorado no P...           ,00
#
#   Valor passagens Valor outros gastos
# 0             ,00                 ,00
# 1             ,00                 ,00
# 2           98,68                 ,00
# 3             ,00                 ,00
# 4             ,00                 ,00
# 5             ,00                 ,00
# 6             ,00                 ,00
# 7         1183,47                 ,00
# 8             ,00                 ,00
# 9          539,75                 ,00

# %%
df.count()
# Out:
# 930964

# %%
# show(truncate=False) Não 'corta' as colunas
# show(2) Exibe somente os dois primeiros registros
# show(10, truncate=False) Exibe os 10 primeiros registros e não corta as colunas
df.select("Nome do órgão superior").show(truncate=False)
# Out:
# +----------------------------------+
# |Nome do órgão superior            |
# +----------------------------------+
# |MINISTERIO DA SAUDE               |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DO MEIO AMBIENTE       |
# |MINISTERIO DA SAUDE               |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DAS RELACOES EXTERIORES|
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DO MEIO AMBIENTE       |
# |MINISTERIO DAS RELACOES EXTERIORES|
# |MINISTERIO DA DEFESA              |
# |MINISTERIO DA DEFESA              |
# |MINISTERIO DA DEFESA              |
# |MINISTERIO DA EDUCACAO            |
# |MINISTERIO DA SAUDE               |
# |ADVOCACIA-GERAL DA UNIAO          |
# +----------------------------------+
# only showing top 20 rows

# %%
# Contar a quantidade de regitros do MINISTERIO DAS RELACOES EXTERIORES
df.filter(df["Nome do órgão superior"]=="MINISTERIO DAS RELACOES EXTERIORES").count()
# Out:
# 5254

# %%
# O Spark executa somente quando passamos o método .show()
df.select("Nome do órgão superior").distinct().show(100, truncate=False)
# Out:
# +---------------------------------------------+
# |Nome do órgão superior                       |
# +---------------------------------------------+
# |MINISTERIO DA JUSTICA E SEGURANCA PUBLICA    |
# |MINISTERIO DA INFRAESTRUTURA                 |
# |MINISTERIO DA SAUDE                          |
# |MINISTERIO DO DESENVOLVIMENTO REGIONAL       |
# |PRESIDENCIA DA REPUBLICA                     |
# |MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS|
# |MINISTERIO DA DEFESA                         |
# |MINISTERIO DAS RELACOES EXTERIORES           |
# |MINISTERIO DO MEIO AMBIENTE                  |
# |MINISTERIO DA CULTURA                        |
# |MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   |
# |MINISTERIO DO ESPORTE                        |
# |MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO |
# |MINISTERIO DA EDUCACAO                       |
# |MINISTERIO DO TURISMO                        |
# |MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO |
# |MINISTERIO DE MINAS E ENERGIA                |
# |MINISTERIO DAS CIDADES                       |
# |ADVOCACIA-GERAL DA UNIAO                     |
# |MINISTERIO DA CIDADANIA                      |
# |CONTROLADORIA-GERAL DA UNIAO                 |
# |MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES|
# |Sem informação                               |
# |MINISTERIO DA ECONOMIA                       |
# |MINISTERIO DO TRABALHO E EMPREGO             |
# +---------------------------------------------+

# %%
# GroupBy
df.groupBy("Nome do órgão superior").count().show(truncate=False)
# Out:
# +---------------------------------------------+------+
# |Nome do órgão superior                       |count |
# +---------------------------------------------+------+
# |MINISTERIO DA JUSTICA E SEGURANCA PUBLICA    |102684|
# |MINISTERIO DA INFRAESTRUTURA                 |22392 |
# |MINISTERIO DA SAUDE                          |53358 |
# |MINISTERIO DO DESENVOLVIMENTO REGIONAL       |9755  |
# |PRESIDENCIA DA REPUBLICA                     |15880 |
# |MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS|1837  |
# |MINISTERIO DA DEFESA                         |110914|
# |MINISTERIO DAS RELACOES EXTERIORES           |5254  |
# |MINISTERIO DO MEIO AMBIENTE                  |34913 |
# |MINISTERIO DA CULTURA                        |1802  |
# |MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   |8614  |
# |MINISTERIO DO ESPORTE                        |984   |
# |MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO |3552  |
# |MINISTERIO DA EDUCACAO                       |292565|
# |MINISTERIO DO TURISMO                        |217   |
# |MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO |60921 |
# |MINISTERIO DE MINAS E ENERGIA                |8821  |
# |MINISTERIO DAS CIDADES                       |1127  |
# |ADVOCACIA-GERAL DA UNIAO                     |9016  |
# |MINISTERIO DA CIDADANIA                      |9933  |
# +---------------------------------------------+------+
# only showing top 20 rows

# %%
# ...orderBy("coluna", ascending=False)
df.groupBy("Nome do órgão superior").count().orderBy("count").show(truncate=False)
# Out:
# +---------------------------------------------+-----+
# |Nome do órgão superior                       |count|
# +---------------------------------------------+-----+
# |Sem informação                               |52   |
# |MINISTERIO DO TURISMO                        |217  |
# |MINISTERIO DO ESPORTE                        |984  |
# |MINISTERIO DAS CIDADES                       |1127 |
# |MINISTERIO DA CULTURA                        |1802 |
# |MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS|1837 |
# |MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO |3552 |
# |CONTROLADORIA-GERAL DA UNIAO                 |3734 |
# |MINISTERIO DAS RELACOES EXTERIORES           |5254 |
# |MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   |8614 |
# |MINISTERIO DE MINAS E ENERGIA                |8821 |
# |ADVOCACIA-GERAL DA UNIAO                     |9016 |
# |MINISTERIO DO DESENVOLVIMENTO REGIONAL       |9755 |
# |MINISTERIO DA CIDADANIA                      |9933 |
# |MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES|13180|
# |PRESIDENCIA DA REPUBLICA                     |15880|
# |MINISTERIO DO TRABALHO E EMPREGO             |17950|
# |MINISTERIO DA INFRAESTRUTURA                 |22392|
# |MINISTERIO DO MEIO AMBIENTE                  |34913|
# |MINISTERIO DA SAUDE                          |53358|
# +---------------------------------------------+-----+
# only showing top 20 rows

# %%
df.groupBy("Nome do órgão superior").count().orderBy("count", ascending=False).show(truncate=False)
# Out:
# +---------------------------------------------+------+
# |Nome do órgão superior                       |count |
# +---------------------------------------------+------+
# |MINISTERIO DA EDUCACAO                       |292565|
# |MINISTERIO DA ECONOMIA                       |141509|
# |MINISTERIO DA DEFESA                         |110914|
# |MINISTERIO DA JUSTICA E SEGURANCA PUBLICA    |102684|
# |MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO |60921 |
# |MINISTERIO DA SAUDE                          |53358 |
# |MINISTERIO DO MEIO AMBIENTE                  |34913 |
# |MINISTERIO DA INFRAESTRUTURA                 |22392 |
# |MINISTERIO DO TRABALHO E EMPREGO             |17950 |
# |PRESIDENCIA DA REPUBLICA                     |15880 |
# |MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES|13180 |
# |MINISTERIO DA CIDADANIA                      |9933  |
# |MINISTERIO DO DESENVOLVIMENTO REGIONAL       |9755  |
# |ADVOCACIA-GERAL DA UNIAO                     |9016  |
# |MINISTERIO DE MINAS E ENERGIA                |8821  |
# |MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   |8614  |
# |MINISTERIO DAS RELACOES EXTERIORES           |5254  |
# |CONTROLADORIA-GERAL DA UNIAO                 |3734  |
# |MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO |3552  |
# |MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS|1837  |
# +---------------------------------------------+------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Identificador do processo de viagem: string (nullable = true)
#  |-- Situação: string (nullable = true)
#  |-- Código do órgão superior: string (nullable = true)
#  |-- Nome do órgão superior: string (nullable = true)
#  |-- Código órgão solicitante: string (nullable = true)
#  |-- Nome órgão solicitante: string (nullable = true)
#  |-- CPF viajante: string (nullable = true)
#  |-- Nome: string (nullable = true)
#  |-- Cargo: string (nullable = true)
#  |-- Período - Data de início: string (nullable = true)
#  |-- Período - Data de fim: string (nullable = true)
#  |-- Destinos: string (nullable = true)
#  |-- Motivo: string (nullable = true)
#  |-- Valor diárias: string (nullable = true)
#  |-- Valor passagens: string (nullable = true)
#  |-- Valor outros gastos: string (nullable = true)

# %%
df.select("Período - Data de início", "Período - Data de fim").show(truncate=False)
# Out:
# +------------------------+---------------------+
# |Período - Data de início|Período - Data de fim|
# +------------------------+---------------------+
# |20180210                |20180302             |
# |20180109                |20181119             |
# |20180223                |20180225             |
# |20180117                |20180216             |
# |20180104                |20180106             |
# |20180108                |20180407             |
# |20180102                |20180405             |
# |20180218                |20180224             |
# |20180201                |20180228             |
# |20180125                |20180126             |
# |20180126                |20180201             |
# |20180225                |20180226             |
# |20180113                |20180213             |
# |20180109                |20180115             |
# |20180124                |20180125             |
# |20180108                |20180111             |
# |20180116                |20180117             |
# |20180112                |20180225             |
# |20180106                |20180210             |
# |20180228                |20180330             |
# +------------------------+---------------------+
# only showing top 20 rows

# %% [markdown]
# Os campos "Período - Data de início" e "Período - Data de fim" estão em um formato que irá dificultar a analise, logo vamos mudar seu formato

# %%
df.select("Valor diárias", "Valor passagens", "Valor outros gastos").show(truncate=False)
# Out:
# +-------------+---------------+-------------------+
# |Valor diárias|Valor passagens|Valor outros gastos|
# +-------------+---------------+-------------------+
# |,00          |,00            |,00                |
# |,00          |,00            |,00                |
# |537,50       |98,68          |,00                |
# |,00          |,00            |,00                |
# |487,11       |,00            |,00                |
# |,00          |,00            |,00                |
# |,00          |,00            |,00                |
# |,00          |1183,47        |,00                |
# |,00          |,00            |,00                |
# |,00          |539,75         |,00                |
# |,00          |767,79         |,00                |
# |,00          |1197,41        |,00                |
# |,00          |,00            |,00                |
# |,00          |3635,74        |,00                |
# |,00          |286,24         |,00                |
# |,00          |2617,12        |,00                |
# |,00          |230,59         |,00                |
# |,00          |,00            |,00                |
# |,00          |,00            |,00                |
# |,00          |,00            |,00                |
# +-------------+---------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# Há vírgulas ao invés de pontos

# %%
from pyspark.sql import functions as F
from pyspark.sql import types

# Função para trocar a vírgula por ponto nos dados de valores do tipo String, e converte o valor para Float
to_value = lambda v : float(v.replace(",", "."))

# Exemplo de uso
to_value("200,00")

# User Defined Function
udf_to_value = F.udf(to_value, types.FloatType())

# %%
df.select("Período - Data de início", "Período - Data de fim").show(truncate=False)
# Out:
# +------------------------+---------------------+
# |Período - Data de início|Período - Data de fim|
# +------------------------+---------------------+
# |20180210                |20180302             |
# |20180109                |20181119             |
# |20180223                |20180225             |
# |20180117                |20180216             |
# |20180104                |20180106             |
# |20180108                |20180407             |
# |20180102                |20180405             |
# |20180218                |20180224             |
# |20180201                |20180228             |
# |20180125                |20180126             |
# |20180126                |20180201             |
# |20180225                |20180226             |
# |20180113                |20180213             |
# |20180109                |20180115             |
# |20180124                |20180125             |
# |20180108                |20180111             |
# |20180116                |20180117             |
# |20180112                |20180225             |
# |20180106                |20180210             |
# |20180228                |20180330             |
# +------------------------+---------------------+
# only showing top 20 rows

# %% [markdown]
# Os campos "Valor diárias", "Valor passagens", "Valor outros gastos" possuem o tipo de dado String, o que irá nos atrapalhar quando for necessário efetuar cálculos com esses campos.

# %%
# Função para trocar a vírgula por ponto nos dados de valores do tipo String, e converte o valor para Float
def to_value(v):
    try:
        return float(v.replace(',','.'))
    except:
        return 0.0
    
udf_to_value = F.udf(to_value, types.FloatType())

# Exemplo de uso
to_value("200,00")
# Out:
# 200.0

# %%
# Criando a coluna "ValorPassagens" a partir da coluna "Valor passagens" transformando a mesma para o tipo Float
# Criando as colunas "PeriodoDataInicio", "PeriodoDataFim" a partir das colunas "Período - Data de início", "Período - Data de fim",
# formatando seus valores para outro padrão

# Função para converter data do formato "yyyyMMdd" para "dd/MM/yyyy"
def convert_to_date(str_date):
    return date_format(unix_timestamp(str_date, "yyyyMMdd").cast("timestamp"), format="dd/MM/yyyy")

df2 = df.withColumn("ValorPassagens", udf_to_value(df["Valor passagens"])) \
        .withColumn("ValorDiarias", udf_to_value(df["Valor diárias"])) \
        .withColumn("ValorOutros", udf_to_value(df["Valor outros gastos"])) \
        .withColumn("PeriodoDataInicio", convert_to_date(df["Período - Data de início"])) \
        .withColumn("PeriodoDataFim", convert_to_date(df["Período - Data de fim"]))

# Convertendo e apresentando as colunas relativas a data
# df.select(convert_to_date("Período - Data de início").alias("Date"), "Período - Data de início").show()

# %%
df2.select("PeriodoDataInicio", "PeriodoDataFim").show(truncate=False)
# Out:
# +-----------------+--------------+
# |PeriodoDataInicio|PeriodoDataFim|
# +-----------------+--------------+
# |10/02/2018       |02/03/2018    |
# |09/01/2018       |19/11/2018    |
# |23/02/2018       |25/02/2018    |
# |17/01/2018       |16/02/2018    |
# |04/01/2018       |06/01/2018    |
# |08/01/2018       |07/04/2018    |
# |02/01/2018       |05/04/2018    |
# |18/02/2018       |24/02/2018    |
# |01/02/2018       |28/02/2018    |
# |25/01/2018       |26/01/2018    |
# |26/01/2018       |01/02/2018    |
# |25/02/2018       |26/02/2018    |
# |13/01/2018       |13/02/2018    |
# |09/01/2018       |15/01/2018    |
# |24/01/2018       |25/01/2018    |
# |08/01/2018       |11/01/2018    |
# |16/01/2018       |17/01/2018    |
# |12/01/2018       |25/02/2018    |
# |06/01/2018       |10/02/2018    |
# |28/02/2018       |30/03/2018    |
# +-----------------+--------------+
# only showing top 20 rows

# %%
# .describe() 
# Este método descreve a coluna que esta sendo passada, calculando quantos registros temos na coluna, média da coluna, desvio padrão, 
# o valor minimo e maximo da coluna.
df2.describe("ValorPassagens").show()
# Out:
# +-------+------------------+
# |summary|    ValorPassagens|
# +-------+------------------+
# |  count|            930964|
# |   mean|497.37188248054196|
# | stddev|1257.6500751273375|
# |    min|               0.0|
# |    max|          436061.1|
# +-------+------------------+

# %%
# Agrupando por orgão superior, a soma de todos os valores das passagens
df2.groupBy("Nome do órgão superior") \
   .agg((F.sum("ValorPassagens") / F.lit(1_000_000)).alias("ValorTotal")) \
   .toPandas()
   #.show(truncate=False)
# Out:
#                            Nome do órgão superior  ValorTotal
# 0       MINISTERIO DA JUSTICA E SEGURANCA PUBLICA   48.953330
# 1                    MINISTERIO DA INFRAESTRUTURA   19.325963
# 2                             MINISTERIO DA SAUDE   30.459403
# 3          MINISTERIO DO DESENVOLVIMENTO REGIONAL    5.478647
# 4                        PRESIDENCIA DA REPUBLICA   17.440636
# 5   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS    4.475031
# 6                            MINISTERIO DA DEFESA   55.014734
# 7              MINISTERIO DAS RELACOES EXTERIORES   18.355391
# 8                     MINISTERIO DO MEIO AMBIENTE   16.398313
# 9                           MINISTERIO DA CULTURA    2.307004
# 10     MINIST. MULHER, FAMILIA E DIREITOS HUMANOS    2.756782
# 11                          MINISTERIO DO ESPORTE    1.470120
# 12   MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO    3.174382
# 13                         MINISTERIO DA EDUCACAO  128.531787
# 14                          MINISTERIO DO TURISMO    0.977132
# 15   MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO   16.078014
# 16                  MINISTERIO DE MINAS E ENERGIA    9.073481
# 17                         MINISTERIO DAS CIDADES    1.326005
# 18                       ADVOCACIA-GERAL DA UNIAO    2.630877
# 19                        MINISTERIO DA CIDADANIA    9.582545
# 20                   CONTROLADORIA-GERAL DA UNIAO    3.254166
# 21  MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES   14.029570
# 22                                 Sem informação    0.225064
# 23                         MINISTERIO DA ECONOMIA   45.487162
# 24               MINISTERIO DO TRABALHO E EMPREGO    6.229777

# %%
# The agg function allows you to perform aggregations on your DataFrame, and returns a new column with the calculated output.
df2.groupBy("Nome do órgão superior") \
   .agg(F.max("ValorPassagens").alias("Valor Máximo"), \
        (F.sum("ValorPassagens") / F.lit(1_000_000)).alias("Soma"), \
        F.count("ValorPassagens").alias("Quantidade"), \
        F.avg("ValorPassagens").alias("Média")) \
    .toPandas()
    #.show(truncate=False)
# Out:
#                            Nome do órgão superior   Valor Máximo        Soma  \
# 0       MINISTERIO DA JUSTICA E SEGURANCA PUBLICA  208208.359375   48.953330
# 1                    MINISTERIO DA INFRAESTRUTURA   26217.839844   19.325963
# 2                             MINISTERIO DA SAUDE   27449.970703   30.459403
# 3          MINISTERIO DO DESENVOLVIMENTO REGIONAL   19421.480469    5.478647
# 4                        PRESIDENCIA DA REPUBLICA   49010.019531   17.440636
# 5   MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS   29188.460938    4.475031
# 6                            MINISTERIO DA DEFESA   86183.789062   55.014734
# 7              MINISTERIO DAS RELACOES EXTERIORES   84791.960938   18.355391
# 8                     MINISTERIO DO MEIO AMBIENTE   56404.671875   16.398313
# 9                           MINISTERIO DA CULTURA   18615.470703    2.307004
# 10     MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   10192.650391    2.756782
# 11                          MINISTERIO DO ESPORTE   24321.109375    1.470120
# 12   MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO   15558.719727    3.174382
# 13                         MINISTERIO DA EDUCACAO  436061.093750  128.531787
# 14                          MINISTERIO DO TURISMO   27838.259766    0.977132
# 15   MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO   52127.929688   16.078014
# 16                  MINISTERIO DE MINAS E ENERGIA   19521.029297    9.073481
# 17                         MINISTERIO DAS CIDADES    8418.200195    1.326005
# 18                       ADVOCACIA-GERAL DA UNIAO   13578.530273    2.630877
# 19                        MINISTERIO DA CIDADANIA   17141.949219    9.582545
# 20                   CONTROLADORIA-GERAL DA UNIAO   18278.609375    3.254166
# 21  MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES   38363.308594   14.029570
# 22                                 Sem informação    8726.580078    0.225064
# 23                         MINISTERIO DA ECONOMIA   41122.050781   45.487162
# 24               MINISTERIO DO TRABALHO E EMPREGO   26702.880859    6.229777
#
#     Quantidade        Média
# 0       102684   476.737666
# 1        22392   863.074446
# 2        53358   570.849784
# 3         9755   561.624527
# 4        15880  1098.276801
# 5         1837  2436.054041
# 6       110914   496.012530
# 7         5254  3493.603250
# 8        34913   469.690733
# 9         1802  1280.246535
# 10        8614   320.035035
# 11         984  1494.024534
# 12        3552   893.688682
# 13      292565   439.327283
# 14         217  4502.913882
# 15       60921   263.915791
# 16        8821  1028.622753
# 17        1127  1176.579054
# 18        9016   291.800894
# 19        9933   964.718114
# 20        3734   871.496052
# 21       13180  1064.459028
# 22          52  4328.153079
# 23      141509   321.443601
# 24       17950   347.062808

# %%
# The agg function allows you to perform aggregations on your DataFrame, and returns a new column with the calculated output.
df2.groupBy("Nome do órgão superior") \
   .agg(F.max("ValorPassagens").alias("Valor Máximo"), \
        (F.sum("ValorPassagens") / F.lit(1_000_000)).alias("Soma"), \
        F.count("ValorPassagens").alias("Quantidade"), \
        F.avg("ValorPassagens").alias("Média")) \
    .orderBy("Soma", ascending=False) \
    .toPandas()
    #.show(truncate=False)
# Out:
#                            Nome do órgão superior   Valor Máximo        Soma  \
# 0                          MINISTERIO DA EDUCACAO  436061.093750  128.531787
# 1                            MINISTERIO DA DEFESA   86183.789062   55.014734
# 2       MINISTERIO DA JUSTICA E SEGURANCA PUBLICA  208208.359375   48.953330
# 3                          MINISTERIO DA ECONOMIA   41122.050781   45.487162
# 4                             MINISTERIO DA SAUDE   27449.970703   30.459403
# 5                    MINISTERIO DA INFRAESTRUTURA   26217.839844   19.325963
# 6              MINISTERIO DAS RELACOES EXTERIORES   84791.960938   18.355391
# 7                        PRESIDENCIA DA REPUBLICA   49010.019531   17.440636
# 8                     MINISTERIO DO MEIO AMBIENTE   56404.671875   16.398313
# 9    MINIST. DA AGRICUL.,PECUARIA E ABASTECIMENTO   52127.929688   16.078014
# 10  MINIST.DA CIENCIA,TECNOL.,INOV.E COMUNICACOES   38363.308594   14.029570
# 11                        MINISTERIO DA CIDADANIA   17141.949219    9.582545
# 12                  MINISTERIO DE MINAS E ENERGIA   19521.029297    9.073481
# 13               MINISTERIO DO TRABALHO E EMPREGO   26702.880859    6.229777
# 14         MINISTERIO DO DESENVOLVIMENTO REGIONAL   19421.480469    5.478647
# 15  MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS   29188.460938    4.475031
# 16                   CONTROLADORIA-GERAL DA UNIAO   18278.609375    3.254166
# 17   MINIST. DO PLANEJAMENTO, DESENVOLV. E GESTAO   15558.719727    3.174382
# 18     MINIST. MULHER, FAMILIA E DIREITOS HUMANOS   10192.650391    2.756782
# 19                       ADVOCACIA-GERAL DA UNIAO   13578.530273    2.630877
# 20                          MINISTERIO DA CULTURA   18615.470703    2.307004
# 21                          MINISTERIO DO ESPORTE   24321.109375    1.470120
# 22                         MINISTERIO DAS CIDADES    8418.200195    1.326005
# 23                          MINISTERIO DO TURISMO   27838.259766    0.977132
# 24                                 Sem informação    8726.580078    0.225064
#
#     Quantidade        Média
# 0       292565   439.327283
# 1       110914   496.012530
# 2       102684   476.737666
# 3       141509   321.443601
# 4        53358   570.849784
# 5        22392   863.074446
# 6         5254  3493.603250
# 7        15880  1098.276801
# 8        34913   469.690733
# 9        60921   263.915791
# 10       13180  1064.459028
# 11        9933   964.718114
# 12        8821  1028.622753
# 13       17950   347.062808
# 14        9755   561.624527
# 15        1837  2436.054041
# 16        3734   871.496052
# 17        3552   893.688682
# 18        8614   320.035035
# 19        9016   291.800894
# 20        1802  1280.246535
# 21         984  1494.024534
# 22        1127  1176.579054
# 23         217  4502.913882
# 24          52  4328.153079

# %% [markdown]
# ## Renomeando colunas

# %%
df2.printSchema()
# Out:
# root
#  |-- Identificador do processo de viagem: string (nullable = true)
#  |-- Situação: string (nullable = true)
#  |-- Código do órgão superior: string (nullable = true)
#  |-- Nome do órgão superior: string (nullable = true)
#  |-- Código órgão solicitante: string (nullable = true)
#  |-- Nome órgão solicitante: string (nullable = true)
#  |-- CPF viajante: string (nullable = true)
#  |-- Nome: string (nullable = true)
#  |-- Cargo: string (nullable = true)
#  |-- Período - Data de início: string (nullable = true)
#  |-- Período - Data de fim: string (nullable = true)
#  |-- Destinos: string (nullable = true)
#  |-- Motivo: string (nullable = true)
#  |-- Valor diárias: string (nullable = true)
#  |-- Valor passagens: string (nullable = true)
#  |-- Valor outros gastos: string (nullable = true)
#  |-- ValorPassagens: float (nullable = true)
#  |-- ValorDiarias: float (nullable = true)
#  |-- ValorOutros: float (nullable = true)
#  |-- PeriodoDataInicio: string (nullable = true)
#  |-- PeriodoDataFim: string (nullable = true)

# %%
# Selecionando as tabelas e criando um novo DataFrame
df3 = df2.select(df2["Nome do órgão superior"].alias("Orgao"), \
                 df2["Nome órgão solicitante"].alias("OrgaoSolicitante"), \
                 df2["Identificador do processo de viagem"].alias("ProcessoViagem"), 
                 df2["ValorPassagens"], df2["PeriodoDataInicio"], df2["PeriodoDataFim"])

df3.printSchema()
# Out:
# root
#  |-- Orgao: string (nullable = true)
#  |-- OrgaoSolicitante: string (nullable = true)
#  |-- ProcessoViagem: string (nullable = true)
#  |-- ValorPassagens: float (nullable = true)
#  |-- PeriodoDataInicio: string (nullable = true)
#  |-- PeriodoDataFim: string (nullable = true)

# %% [markdown]
# Criando arquivos Parquet para armazenamento de dados

# %%
# Escrevendo um arquivo parquet com o DataFrame DF3
df3.write.parquet("viagens.parquet")

# %%
# Lendo um arquivo parquet
df_parquet = spark.read.parquet("viagens.parquet")

# %%
df_parquet.count()
# Out:
# 930964

# %%
df_parquet.describe().toPandas() #show(truncate=False)
# Out:
#   summary                     Orgao  \
# 0   count                    930964
# 1    mean                      None
# 2  stddev                      None
# 3     min  ADVOCACIA-GERAL DA UNIAO
# 4     max            Sem informação
#
#                                     OrgaoSolicitante        ProcessoViagem  \
# 0                                             930964                930964
# 1                                               None  2.0387903129999656E7
# 2                                               None  1.0235684938371031E8
# 3  ADVOCACIA-GERAL DA UNIAO - UNIDADES COM VÍNCUL...   0000000000013501576
# 4      VALEC-ENGENHARIA, CONSTRUCOES E FERROVIAS S/A   0000000002018004078
#
#        ValorPassagens PeriodoDataInicio PeriodoDataFim
# 0              930964            930964         930964
# 1   497.3718824805419              None           None
# 2  1257.6500751273375              None           None
# 3                 0.0        01/01/2018     01/01/2018
# 4            436061.1        31/12/2018     31/12/2018
